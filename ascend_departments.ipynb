# %%
# Import the necessary modules

import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical computations

import matplotlib.pyplot as plt  # For plotting
import seaborn as sns  # For statistical data visualization

# %%
# Load the dataset

ascend_departments = pd.read_csv('C:/Users/BrindhaGanesan/OneDrive - IMMIGRANT EMPLOYMENT COUNCIL OF BC SOCIETY/Documents/ASCEND/Datasets/ascend_departments.csv')
ascend_departments.head()
# Out:
#                                      NAME  \
# 0                         ACS Facilitator
# 1  Actions Interculturelles Canada (AIDE)
# 2                      AFNOO Facilitators
# 3                                    AFRY
# 4                       AFRY Facilitators
#
#                                          PARENT NAME  # OF USERS  \
# 0                   Archway Community Services (ACS)           0
# 1                 Immigrant Employment Council of BC           0
# 2  Association des Francophones du Nord‑Ouest de ...           0
# 3                 Immigrant Employment Council of BC           6
# 4                                               AFRY           1
#
#    # OF LEARNERS  # OF ADMINS             DATE ADDED
# 0              0            0  2022-05-19 4:06:40 PM
# 1              0            0  2024-02-15 2:30:57 PM
# 2              0            0  2024-04-26 2:29:29 PM
# 3              6            0  2024-03-06 2:45:14 PM
# ...

# %%
ascend_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NAME           131 non-null    object
#  1   PARENT NAME    130 non-null    object
#  2   # OF USERS     131 non-null    int64
#  3   # OF LEARNERS  131 non-null    int64
#  4   # OF ADMINS    131 non-null    int64
#  5   DATE ADDED     131 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 6.3+ KB

# %%
ascend_departments.shape
# Out:
# (131, 6)

# %%
ascend_departments.head(50)
# Out:
#                                                  NAME  \
# 0                                     ACS Facilitator
# 1              Actions Interculturelles Canada (AIDE)
# 2                                  AFNOO Facilitators
# 3                                                AFRY
# 4                                   AFRY Facilitators
# 5                                   AIDE Facilitators
# 6                    Archway Community Services (ACS)
# 7                                         ASCEND Demo
# 8                                     ASCEND Français
# 9                        ASCEND Français - Individual
# 10                               ASCEND Français Demo
# 11                        ASCEND French Facilitators
# 12                        ASCEND Prospective Partners
# 13                            ASCEND public interface
# 14                                     ASCEND Testers
# 15  Association des Francophones du Nord‑Ouest de ...
# ...

# %%
ascend_departments['PARENT NAME'].unique()
# Out:
# array(['Archway Community Services (ACS)',
#        'Immigrant Employment Council of BC',
#        'Association des Francophones du Nord‑Ouest de l’Ontario (AFNOO)',
#        'AFRY', 'Actions Interculturelles Canada (AIDE)',
#        'ASCEND Français', 'BC JobConnect & MentorConnect (BCJC & BCMC)',
#        'Back in Motion (BIM)',
#        'Black Coalition for AIDS Prevention (Black CAP)', 'CDENE',
#        'Center For Skills Development (CFSDT)',
#        "Calgary Immigrant Women's Association (CIWA)",
#        "Calgary Immigrant Women's Association - Labour Market Bridging (CIWA LMB)",
#        'Calgary Region Immigrant Employment Council (CRIEC)', 'CSEPR',
#        'Central Vancouver Island Multicultural Society (CVIMS)',
#        'Douglas College (DC)', 'Francophonie Canadienne Plurielle (FRAP)',
#        'Global Gathering Place (GGP)', nan, 'Impact North Shore (INS)',
#        'ISS of BC', 'Kelowna Community Resources (KCR)', 'KEYS',
# ...

# %%
ascend_departments['NAME'].unique()
# Out:
# array(['ACS Facilitator', 'Actions Interculturelles Canada (AIDE)',
#        'AFNOO Facilitators', 'AFRY', 'AFRY Facilitators',
#        'AIDE Facilitators', 'Archway Community Services (ACS)',
#        'ASCEND Demo', 'ASCEND Français', 'ASCEND Français - Individual',
#        'ASCEND Français Demo', 'ASCEND French Facilitators ',
#        'ASCEND Prospective Partners', 'ASCEND public interface',
#        'ASCEND Testers',
#        'Association des Francophones du Nord‑Ouest de l’Ontario (AFNOO)',
#        'Back in Motion (BIM)',
#        'BC JobConnect & MentorConnect (BCJC & BCMC)',
#        'BCJC & BCMC Facilitators', 'BIM Facilitators',
#        'Black Coalition for AIDS Prevention (Black CAP)',
#        'Black-CAP Facilitator',
#        "Calgary Immigrant Women's Association - Labour Market Bridging (CIWA LMB)",
#        "Calgary Immigrant Women's Association (CIWA)",
#        'Calgary Region Immigrant Employment Council (CRIEC)', 'CDENE',
# ...

# %%
ascend_departments['PARENT NAME'].value_counts()
# Out:
# PARENT NAME
# Immigrant Employment Council of BC                                           72
# ASCEND Français                                                               3
# Central Vancouver Island Multicultural Society (CVIMS)                        2
# Francophonie Canadienne Plurielle (FRAP)                                      2
# Archway Community Services (ACS)                                              1
# Peel District School Board (PDSB)                                             1
# Polycultural Immigrant & Community Services (PIACS)                           1
# Progressive Intercultural Community Services (PICS) Society                   1
# Pacific Immigrant Resources Society (PIRS)                                    1
# ASCEND public interface                                                       1
# Regina Immigrant Women's Centre (RIWC)                                        1
# Rural Manitoba Immigrant Employment Council (RMIEC)                           1
# ...

# %%
ascend_departments['NAME'].value_counts()
# Out:
# NAME
# FRAP Facilitators               2
# ACS Facilitator                 1
# SDECB Facilitators              1
# Sample Users - Group 2          1
# Sample Users - Group 1          1
#                                ..
# DC Facilitators                 1
# CVIMS International Students    1
# CVIMS Facilitators              1
# CSEPR Facilitators              1
# YWCA Metro Vancouver            1
# Name: count, Length: 130, dtype: int64

# %%
# Adjust the display settings to show more rows
pd.set_option('display.max_rows', None)

# %%
ascend_departments['NAME'].value_counts()
# Out:
# NAME
# FRAP Facilitators                                                            2
# ACS Facilitator                                                              1
# SDECB Facilitators                                                           1
# Sample Users - Group 2                                                       1
# Sample Users - Group 1                                                       1
# Sample SDP for testing reports - NH                                          1
# Saint John Newcomers Centre (SJNC)                                           1
# Rural Manitoba Immigrant Employment Council (RMIEC)                          1
# Rooted Connections Facilitators                                              1
# Rooted Connections (previously CFS Regina)                                   1
# RMIEC Facilitators                                                           1
# RIWC Facilitators                                                            1
# ...

# %%
len(ascend_departments['NAME'].value_counts())
# Out:
# 130
